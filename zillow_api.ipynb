# %%
#libraries
import pandas as pd
import numpy as np
import plotly.express as px
import requests
import warnings

#settings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

#API key
with open('../keys/scrapeak', 'r') as file:
    API_KEY = file.readline().replace("\n", "").replace(" ", "")

# %%
#define functions
def get_listings(api_key, listing_url):
    #/ Set your API key and listing URL
    parameters= {
        "api_key": api_key,
        "url": listing_url
    }
    #/ API endpoint and default headers
    api_url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"

    #/ Make the API request
    response = requests.get(api_url, params=parameters)
    return response

# %%
print(listing_response)
# Out:
# <Response [200]>

# %%
# zillow search url
listing_url = "https://www.zillow.com/petworth-washington-dc/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22west%22%3A-77.03855641549683%2C%22east%22%3A-76.99791558450318%2C%22south%22%3A38.92739512733399%2C%22north%22%3A38.96541122778814%7D%2C%22usersSearchTerm%22%3A%22Petworth%2C%20Washington%2C%20DC%22%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A121774%2C%22regionType%22%3A8%7D%5D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22price%22%3A%7B%22max%22%3A18000000%7D%2C%22mp%22%3A%7B%22max%22%3A92729%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A15%7D"

# get listings
listing_response = get_listings(API_KEY, listing_url)

# %%
#view keyes
listing_response.json().keys()
# Out:
# dict_keys(['is_success', 'data', 'message'])

# %%
# check if request is successful
listing_response.json()["is_success"]
# Out:
# True

# %%
# view count of properies returned in request
num_of_properties = listing_response.json()["data"]["categoryTotals"]["cat1"]["totalResultCount"]
print("Count of properties:", num_of_properties)
# Out:
# Count of properties: 76

# %%
# view all listings
df_listings = pd.json_normalize(listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"])
print("Number of rows:", len(df_listings))
print("Number of columns:", len(df_listings.columns))
df_listings
# Out:
# Number of rows: 74
# Number of columns: 92
#           zpid rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0    311114460         ForSale           For Sale by Agent
# 1       484164         ForSale           For Sale by Agent
# 2       485842         ForSale           For Sale by Agent
# 3       487066         ForSale           For Sale by Agent
# 4       484340         ForSale           For Sale by Agent
# ..         ...             ...                         ...
# 69      486787         ForSale           For Sale by Agent
# 70      486659         ForSale           For Sale by Agent
# 71      484916         ForSale           For Sale by Agent
# 72  2125660005         ForSale           For Sale by Agent
# 73  2056986950         ForSale           For Sale by Agent
#
#                                                imgSrc hasImage  \
# 0   https://photos.zillowstatic.com/fp/bdffe4763d2...     True
# 1   https://photos.zillowstatic.com/fp/a7c0ecca93c...     True
# 2   https://photos.zillowstatic.com/fp/af76d7b276f...     True
# 3   https://photos.zillowstatic.com/fp/cb29252ce6a...     True
# 4   https://photos.zillowstatic.com/fp/a7e751fb5cd...     True
# ..                                                ...      ...
# 69  https://photos.zillowstatic.com/fp/c5f2ff4fd7e...     True
# 70  https://photos.zillowstatic.com/fp/c6073a32d84...     True
# 71  https://maps.googleapis.com/maps/api/staticmap...      NaN
# 72  https://photos.zillowstatic.com/fp/97066932938...     True
# 73  https://photos.zillowstatic.com/fp/5724ef66b32...     True
#
#                                             detailUrl statusType  \
# 0   /homedetails/820-Kennedy-St-NW-UNIT-3-Washingt...   FOR_SALE
# 1   /homedetails/640-Hamilton-St-NW-Washington-DC-...   FOR_SALE
# 2   /homedetails/5325-5th-St-NW-Washington-DC-2001...   FOR_SALE
# 3   /homedetails/332-Allison-St-NW-Washington-DC-2...   FOR_SALE
# 4   /homedetails/634-Farragut-St-NW-Washington-DC-...   FOR_SALE
# ..                                                ...        ...
# 69  /homedetails/5003-4th-St-NW-Washington-DC-2001...   FOR_SALE
# 70  /homedetails/5414-3rd-St-NW-Washington-DC-2001...   FOR_SALE
# 71  /homedetails/3927-7th-St-NW-Washington-DC-2001...   FOR_SALE
# 72  /homedetails/222-Upshur-St-NW-Washington-DC-20...   FOR_SALE
# 73  /homedetails/0-N-St-SE-Washington-DC-20019/205...   FOR_SALE
#
#                     statusText       price priceLabel  \
# 0               Condo for sale    $649,997      $650K
# 1           Townhouse for sale    $749,900      $750K
# 2           Townhouse for sale    $825,000      $825K
# 3           Townhouse for sale    $499,900      $500K
# 4           Townhouse for sale    $849,900      $850K
# ..                         ...         ...        ...
# 69          Townhouse for sale    $895,000      $895K
# 70  Multi-family home for sale    $999,000      $999K
# 71          Townhouse for sale  $1,700,000     $1.70M
# 72  Multi-family home for sale    $875,000      $875K
# 73         Lot / Land for sale    $192,500      $193K
#
#                                            address  beds  baths    area  \
# 0   820 Kennedy St NW UNIT 3, Washington, DC 20011   3.0    3.0  1243.0
# 1         640 Hamilton St NW, Washington, DC 20011   3.0    4.0   832.0
# 2             5325 5th St NW, Washington, DC 20011   3.0    4.0  1911.0
# 3          332 Allison St NW, Washington, DC 20011   3.0    2.0  2251.0
# 4         634 Farragut St NW, Washington, DC 20011   4.0    4.0  1897.0
# ..                                             ...   ...    ...     ...
# 69            5003 4th St NW, Washington, DC 20011   4.0    2.0  2144.0
# 70            5414 3rd St NW, Washington, DC 20011   4.0    NaN  2870.0
# 71            3927 7th St NW, Washington, DC 20011   8.0    3.0  2983.0
# 72          222 Upshur St NW, Washington, DC 20011   2.0    NaN     0.0
# 73                 0 N St SE, Washington, DC 20019   NaN    NaN     NaN
#
#    isUserClaimingOwner isUserConfirmedClaim    pgapt              sgapt  \
# 0                False                False  ForSale  For Sale (Broker)
# 1                False                False  ForSale  For Sale (Broker)
# 2                False                False  ForSale  For Sale (Broker)
# 3                False                False  ForSale  For Sale (Broker)
# 4                False                False  ForSale  For Sale (Broker)
# ..                 ...                  ...      ...                ...
# 69               False                False  ForSale  For Sale (Broker)
# 70               False                False  ForSale  For Sale (Broker)
# 71               False                False  ForSale  For Sale (Broker)
# 72               False                False  ForSale  For Sale (Broker)
# 73               False                False  ForSale  For Sale (Broker)
#
#    shouldShowZestimateAsPrice  has3DModel hasVideo  isHomeRec  \
# 0                       False       False    False      False
# 1                       False       False    False      False
# 2                       False       False    False      False
# 3                       False       False    False      False
# 4                       False       False    False      False
# ..                        ...         ...      ...        ...
# 69                      False       False    False      False
# 70                      False       False    False      False
# 71                      False       False    False      False
# 72                      False       False    False      False
# 73                      False       False    False      False
#
#     hasAdditionalAttributions  isFeaturedListing  isShowcaseListing  \
# 0                        True              False              False
# 1                        True              False              False
# 2                        True              False              False
# 3                        True              False              False
# 4                        True              False              False
# ..                        ...                ...                ...
# 69                       True              False              False
# 70                       True              False              False
# 71                       True              False              False
# 72                       True              False              False
# 73                       True              False              False
#
#    listingType  isFavorite visited  \
# 0                    False   False
# 1                    False   False
# 2                    False   False
# 3                    False   False
# 4                    False   False
# ..         ...         ...     ...
# 69                   False   False
# 70                   False   False
# 71                   False   False
# 72                   False   False
# 73                   False   False
#
#                                           info3String  \
# 0   https://photos.zillowstatic.com/fp/3c0b241c63a...
# 1   https://photos.zillowstatic.com/fp/3c0b241c63a...
# 2   https://photos.zillowstatic.com/fp/3c0b241c63a...
# 3   https://photos.zillowstatic.com/fp/3c0b241c63a...
# 4   https://photos.zillowstatic.com/fp/3c0b241c63a...
# ..                                                ...
# 69  https://photos.zillowstatic.com/fp/3c0b241c63a...
# 70  https://photos.zillowstatic.com/fp/3c0b241c63a...
# 71  https://photos.zillowstatic.com/fp/3c0b241c63a...
# 72  https://photos.zillowstatic.com/fp/3c0b241c63a...
# 73  https://photos.zillowstatic.com/fp/3c0b241c63a...
#
#                            brokerName  timeOnZillow  latLong.latitude  \
# 0            RE/MAX Excellence Realty     151314000         38.956120
# 1                     KW Metro Center     151314000         38.952900
# 2                  Bidwell Properties     151314000         38.954990
# 3                RE/MAX Professionals     756114000         38.945120
# 4                             Compass     324114000         38.950813
# ..                                ...           ...               ...
# 69                  EXIT Right Realty    6717714000         38.951290
# 70                   DMV Realty, INC.    4471314000         38.956000
# 71                          BUYSELLDC    3434514000         38.939560
# 72                  EXIT Right Realty   10778514000         38.941990
# 73  Realty One Group Performance, LLC   24948114000         38.950510
#
#     latLong.longitude variableData.type  variableData.text  \
# 0          -77.024880        OPEN_HOUSE   Open: Sat. 2-3pm
# 1          -77.021450               NaN                NaN
# 2          -77.019590        OPEN_HOUSE   Open: Sun. 2-4pm
# 3          -77.016940               NaN                NaN
# 4          -77.021286        OPEN_HOUSE   Open: Sat. 2-4pm
# ..                ...               ...                ...
# 69         -77.017260               NaN                NaN
# 70         -77.016330   PRICE_REDUCTION  $100,000 (Mar 27)
# 71         -77.021250               NaN                NaN
# 72         -77.014780               NaN                NaN
# 73         -77.008880               NaN                NaN
#
#     hdpData.homeInfo.zpid hdpData.homeInfo.streetAddress  \
# 0            3.111145e+08       820 Kennedy St NW UNIT 3
# 1            4.841640e+05             640 Hamilton St NW
# 2            4.858420e+05                 5325 5th St NW
# 3            4.870660e+05              332 Allison St NW
# 4            4.843400e+05             634 Farragut St NW
# ..                    ...                            ...
# 69           4.867870e+05                 5003 4th St NW
# 70           4.866590e+05                 5414 3rd St NW
# 71           4.849160e+05                 3927 7th St NW
# 72           2.125660e+09               222 Upshur St NW
# 73           2.056987e+09                      0 N St SE
#
#    hdpData.homeInfo.zipcode hdpData.homeInfo.city hdpData.homeInfo.state  \
# 0                     20011            Washington                     DC
# 1                     20011            Washington                     DC
# 2                     20011            Washington                     DC
# 3                     20011            Washington                     DC
# 4                     20011            Washington                     DC
# ..                      ...                   ...                    ...
# 69                    20011            Washington                     DC
# 70                    20011            Washington                     DC
# 71                    20011            Washington                     DC
# 72                    20011            Washington                     DC
# 73                    20019            Washington                     DC
#
#     hdpData.homeInfo.latitude  hdpData.homeInfo.longitude  \
# 0                   38.956120                  -77.024880
# 1                   38.952900                  -77.021450
# 2                   38.954990                  -77.019590
# 3                   38.945120                  -77.016940
# 4                   38.950813                  -77.021286
# ..                        ...                         ...
# 69                  38.951290                  -77.017260
# 70                  38.956000                  -77.016330
# 71                  38.939560                  -77.021250
# 72                  38.941990                  -77.014780
# 73                  38.950510                  -77.008880
#
#     hdpData.homeInfo.price  hdpData.homeInfo.bathrooms  \
# 0                 649997.0                         3.0
# 1                 749900.0                         4.0
# 2                 825000.0                         4.0
# 3                 499900.0                         2.0
# 4                 849900.0                         4.0
# ..                     ...                         ...
# 69                895000.0                         2.0
# 70                999000.0                         NaN
# 71               1700000.0                         3.0
# 72                875000.0                         NaN
# 73                192500.0                         NaN
#
#     hdpData.homeInfo.bedrooms  hdpData.homeInfo.livingArea  \
# 0                         3.0                       1243.0
# 1                         3.0                        832.0
# 2                         3.0                       1911.0
# 3                         3.0                       2251.0
# 4                         4.0                       1897.0
# ..                        ...                          ...
# 69                        4.0                       2144.0
# 70                        4.0                       2870.0
# 71                        8.0                       2983.0
# 72                        2.0                          0.0
# 73                        NaN                          NaN
#
#    hdpData.homeInfo.homeType hdpData.homeInfo.homeStatus  \
# 0                      CONDO                    FOR_SALE
# 1                  TOWNHOUSE                    FOR_SALE
# 2                  TOWNHOUSE                    FOR_SALE
# 3                  TOWNHOUSE                    FOR_SALE
# 4                  TOWNHOUSE                    FOR_SALE
# ..                       ...                         ...
# 69                 TOWNHOUSE                    FOR_SALE
# 70              MULTI_FAMILY                    FOR_SALE
# 71                 TOWNHOUSE                    FOR_SALE
# 72              MULTI_FAMILY                    FOR_SALE
# 73                       LOT                    FOR_SALE
#
#     hdpData.homeInfo.daysOnZillow hdpData.homeInfo.isFeatured  \
# 0                            -1.0                       False
# 1                            -1.0                       False
# 2                            -1.0                       False
# 3                            -1.0                       False
# 4                            -1.0                       False
# ..                            ...                         ...
# 69                           -1.0                       False
# 70                           -1.0                       False
# 71                           -1.0                       False
# 72                           -1.0                       False
# 73                           -1.0                       False
#
#    hdpData.homeInfo.shouldHighlight  hdpData.homeInfo.zestimate  \
# 0                             False                    637100.0
# 1                             False                    757600.0
# 2                             False                         NaN
# 3                             False                    501700.0
# 4                             False                    859300.0
# ..                              ...                         ...
# 69                            False                    864900.0
# 70                            False                    967500.0
# 71                            False                   1638100.0
# 72                            False                    869300.0
# 73                            False                         NaN
#
#     hdpData.homeInfo.rentZestimate hdpData.homeInfo.listing_sub_type.is_FSBA  \
# 0                           3300.0                                      True
# 1                           2394.0                                      True
# 2                              NaN                                      True
# 3                           3587.0                                      True
# 4                           2388.0                                      True
# ..                             ...                                       ...
# 69                          3896.0                                      True
# 70                          4626.0                                      True
# 71                          7048.0                                      True
# 72                          3576.0                                      True
# 73                          2100.0                                      True
#
#    hdpData.homeInfo.listing_sub_type.is_openHouse hdpData.homeInfo.openHouse  \
# 0                                            True                 Sat. 2-3pm
# 1                                             NaN                        NaN
# 2                                            True                 Sun. 2-4pm
# 3                                             NaN                        NaN
# 4                                            True                 Sat. 2-4pm
# ..                                            ...                        ...
# 69                                            NaN                        NaN
# 70                                            NaN                        NaN
# 71                                            NaN                        NaN
# 72                                            NaN                        NaN
# 73                                            NaN                        NaN
#
#    hdpData.homeInfo.isUnmappable hdpData.homeInfo.isPreforeclosureAuction  \
# 0                          False                                    False
# 1                          False                                    False
# 2                          False                                    False
# 3                          False                                    False
# 4                          False                                    False
# ..                           ...                                      ...
# 69                         False                                    False
# 70                         False                                    False
# 71                         False                                    False
# 72                         False                                    False
# 73                         False                                    False
#
#    hdpData.homeInfo.homeStatusForHDP  hdpData.homeInfo.priceForHDP  \
# 0                           FOR_SALE                      649997.0
# 1                           FOR_SALE                      749900.0
# 2                           FOR_SALE                      825000.0
# 3                           FOR_SALE                      499900.0
# 4                           FOR_SALE                      849900.0
# ..                               ...                           ...
# 69                          FOR_SALE                      895000.0
# 70                          FOR_SALE                      999000.0
# 71                          FOR_SALE                     1700000.0
# 72                          FOR_SALE                      875000.0
# 73                          FOR_SALE                      192500.0
#
#    hdpData.homeInfo.open_house_info.open_house_showing  \
# 0   [{'open_house_start': 1712437200000, 'open_hou...
# 1                                                 NaN
# 2   [{'open_house_start': 1712523600000, 'open_hou...
# 3                                                 NaN
# 4   [{'open_house_start': 1712437200000, 'open_hou...
# ..                                                ...
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
# 72                                                NaN
# 73                                                NaN
#
#     hdpData.homeInfo.timeOnZillow hdpData.homeInfo.isNonOwnerOccupied  \
# 0                    1.513140e+08                                True
# 1                    1.513140e+08                                True
# 2                    1.513140e+08                                True
# 3                    7.561140e+08                                True
# 4                    3.241140e+08                                True
# ..                            ...                                 ...
# 69                   6.717714e+09                                True
# 70                   4.471314e+09                                True
# 71                   3.434514e+09                                True
# 72                   1.077851e+10                                True
# 73                   2.494811e+10                                True
#
#    hdpData.homeInfo.isPremierBuilder hdpData.homeInfo.isZillowOwned  \
# 0                              False                          False
# 1                              False                          False
# 2                              False                          False
# 3                              False                          False
# 4                              False                          False
# ..                               ...                            ...
# 69                             False                          False
# 70                             False                          False
# 71                             False                          False
# 72                             False                          False
# 73                             False                          False
#
#    hdpData.homeInfo.currency hdpData.homeInfo.country  \
# 0                        USD                      USA
# 1                        USD                      USA
# 2                        USD                      USA
# 3                        USD                      USA
# 4                        USD                      USA
# ..                       ...                      ...
# 69                       USD                      USA
# 70                       USD                      USA
# 71                       USD                      USA
# 72                       USD                      USA
# 73                       USD                      USA
#
#     hdpData.homeInfo.taxAssessedValue hdpData.homeInfo.unit  \
# 0                            601760.0                Unit 3
# 1                            610330.0                   NaN
# 2                            940770.0                   NaN
# 3                            746290.0                   NaN
# 4                            829140.0                   NaN
# ..                                ...                   ...
# 69                           709030.0                   NaN
# 70                           962490.0                   NaN
# 71                           871660.0                   NaN
# 72                                NaN                   NaN
# 73                                NaN                   NaN
#
#    hdpData.homeInfo.isShowcaseListing  hdpData.homeInfo.lotAreaValue  \
# 0                               False                            NaN
# 1                               False                         2200.0
# 2                               False                         1588.0
# 3                               False                         2850.0
# 4                               False                         2545.0
# ..                                ...                            ...
# 69                              False                         1700.0
# 70                              False                         3325.0
# 71                              False                         2500.0
# 72                              False                         3113.0
# 73                              False                         2539.0
#
#    hdpData.homeInfo.lotAreaUnit  hdpData.homeInfo.datePriceChanged  \
# 0                           NaN                                NaN
# 1                          sqft                                NaN
# 2                          sqft                                NaN
# 3                          sqft                                NaN
# 4                          sqft                                NaN
# ..                          ...                                ...
# 69                         sqft                                NaN
# 70                         sqft                       1.711523e+12
# 71                         sqft                                NaN
# 72                         sqft                                NaN
# 73                         sqft                                NaN
#
#    hdpData.homeInfo.priceReduction  hdpData.homeInfo.priceChange  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# ..                             ...                           ...
# 69                             NaN                           NaN
# 70               $100,000 (Mar 27)                     -100000.0
# 71                             NaN                           NaN
# 72                             NaN                           NaN
# 73                             NaN                           NaN
#
#    hdpData.homeInfo.listing_sub_type.is_comingSoon  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 69                                             NaN
# 70                                             NaN
# 71                                             NaN
# 72                                             NaN
# 73                                             NaN
#
#    hdpData.homeInfo.listing_sub_type.is_newHome  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 69                                          NaN
# 70                                          NaN
# 71                                          NaN
# 72                                          NaN
# 73                                          NaN
#
#    hdpData.homeInfo.newConstructionType  hdpData.homeInfo.videoCount  minBeds  \
# 0                                   NaN                          NaN      NaN
# 1                                   NaN                          NaN      NaN
# 2                                   NaN                          NaN      NaN
# 3                                   NaN                          NaN      NaN
# 4                                   NaN                          NaN      NaN
# ..                                  ...                          ...      ...
# 69                                  NaN                          NaN      NaN
# 70                                  NaN                          NaN      NaN
# 71                                  NaN                          NaN      NaN
# 72                                  NaN                          NaN      NaN
# 73                                  NaN                          NaN      NaN
#
#     minBaths  minArea  lotId buildingId isBuilding canSaveBuilding  unitCount  \
# 0        NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 1        NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 2        NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 3        NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 4        NaN      NaN    NaN        NaN        NaN             NaN        NaN
# ..       ...      ...    ...        ...        ...             ...        ...
# 69       NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 70       NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 71       NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 72       NaN      NaN    NaN        NaN        NaN             NaN        NaN
# 73       NaN      NaN    NaN        NaN        NaN             NaN        NaN
#
#    buildingName builderName  \
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN         NaN
# 4           NaN         NaN
# ..          ...         ...
# 69          NaN         NaN
# 70          NaN         NaN
# 71          NaN         NaN
# 72          NaN         NaN
# 73          NaN         NaN
#
#                                         streetViewURL  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 69                                                NaN
# 70                                                NaN
# 71  https://maps.googleapis.com/maps/api/streetvie...
# 72                                                NaN
# 73                                                NaN
#
#                                 streetViewMetadataURL lotAreaString
# 0                                                 NaN           NaN
# 1                                                 NaN           NaN
# 2                                                 NaN           NaN
# 3                                                 NaN           NaN
# 4                                                 NaN           NaN
# ..                                                ...           ...
# 69                                                NaN           NaN
# 70                                                NaN           NaN
# 71  https://maps.googleapis.com/maps/api/streetvie...           NaN
# 72                                                NaN           NaN
# 73                                                NaN    2,539 sqft
#
# [74 rows x 92 columns]
