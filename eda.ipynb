# %%
library(tidyverse)
library(ggcorrplot)

# %%
df = read.csv("./data/cleaned_listing_dc.csv")
cleaned_df = df %>% dplyr::select(host_has_profile_pic, host_identity_verified, longitude, latitude, accommodates, bathrooms, beds, price, number_of_reviews, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, review_scores_communication, review_scores_location, review_scores_value, instant_bookable, reviews_per_month, host_length)

# %%
numeric_cols = cleaned_df[, sapply(cleaned_df, is.numeric)]

# %%
mx = cor(numeric_cols[,c(1,2,3,4,5,6,7)])
ggcorrplot(mx, hc.order = TRUE, type = "lower", lab=TRUE, title = "Correlation between features")
# Out:
# plot without title

# %%
head(cleaned_df)
# Out:
#   host_has_profile_pic host_identity_verified longitude latitude accommodates
# 1 t                    t                      -77.04008 38.91887 3
# 2 t                    t                      -77.09774 38.91999 2
# 3 t                    t                      -77.07591 38.92622 4
# 4 t                    t                      -77.03136 38.92836 2
# 5 t                    t                      -76.99133 38.90053 4
# 6 t                    t                      -77.00645 38.96650 1
#   bathrooms beds price number_of_reviews review_scores_rating
# 1 1         1     60    96               4.50
# 2 1         2     66    91               4.79
# 3 1         3     85   412               4.59
# 4 1         2    125    38               4.84
# 5 1         3    645    13               4.77
# 6 1         1     65    11               5.00
#   review_scores_accuracy review_scores_cleanliness review_scores_checkin
# 1 4.71                   4.13                      4.82
# 2 4.77                   4.87                      4.94
# 3 4.65                   4.60                      4.86
# 4 4.92                   4.84                      5.00
# 5 4.50                   4.25                      4.75
# 6 4.60                   4.80                      5.00
#   review_scores_communication review_scores_location review_scores_value
# 1 4.82                        4.91                   4.44
# 2 4.90                        4.79                   4.81
# 3 4.88                        4.83                   4.59
# 4 4.97                        4.76                   4.84
# 5 4.75                        5.00                   4.75
# 6 5.00                        4.20                   4.40
#   instant_bookable reviews_per_month host_length
# 1 f                0.55              5568
# 2 f                0.54              5443
# 3 f                2.43              5353
# 4 f                0.23              5264
# 5 f                0.08              5094
# 6 f                0.07              5332

# %%
cleaned_df %>%
ggplot(aes(x = price)) +
geom_density(alpha = 0.5)
# Out:
# plot without title
